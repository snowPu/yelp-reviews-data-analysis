# %%
import numpy as np
import pandas as pd
import csv
import json
import matplotlib.pyplot as plt
from datetime import datetime
from tqdm import tqdm 
# %matplotlib inline

# %%
PATH_TO_FILE = "yelp_academic_dataset_checkin.csv"

# %%
df = pd.read_csv(PATH_TO_USER_FILE)

# %%
nrow = df.shape[0]

# %%
times = [col for col in df.columns if 'time.' in col]
checkins = dict.fromkeys(times, 0)
for key in checkins.keys():
    df[key].fillna(0)
    checkins[key] = df[key].max()
checkins
# Out:
# {'time.Fri-0': 1132.0,
#  'time.Fri-1': 1332.0,
#  'time.Fri-10': 456.0,
#  'time.Fri-11': 434.0,
#  'time.Fri-12': 588.0,
#  'time.Fri-13': 789.0,
#  'time.Fri-14': 1115.0,
#  'time.Fri-15': 1275.0,
#  'time.Fri-16': 1288.0,
#  'time.Fri-17': 1308.0,
#  'time.Fri-18': 1308.0,
#  'time.Fri-19': 1275.0,
#  'time.Fri-2': 1263.0,
#  'time.Fri-20': 1214.0,
#  'time.Fri-21': 1281.0,
#  'time.Fri-22': 1340.0,
#  'time.Fri-23': 1505.0,
#  'time.Fri-3': 1193.0,
#  'time.Fri-4': 1220.0,
#  'time.Fri-5': 1118.0,
#  'time.Fri-6': 886.0,
#  'time.Fri-7': 492.0,
#  'time.Fri-8': 204.0,
#  'time.Fri-9': 166.0,
#  'time.Mon-0': 1421.0,
#  'time.Mon-1': 1442.0,
#  'time.Mon-10': 482.0,
#  'time.Mon-11': 516.0,
#  'time.Mon-12': 745.0,
#  'time.Mon-13': 1039.0,
#  'time.Mon-14': 1215.0,
#  'time.Mon-15': 1480.0,
#  'time.Mon-16': 1375.0,
#  'time.Mon-17': 1283.0,
#  'time.Mon-18': 1265.0,
#  'time.Mon-19': 1222.0,
#  'time.Mon-2': 1397.0,
#  'time.Mon-20': 1188.0,
#  'time.Mon-21': 1215.0,
# ...

# %%
df[df['time.Fri-0']==1132]
# Out:
#        time.Wed-17  time.Wed-2  time.Sun-4  time.Sun-7  time.Mon-12  \
# 24463        811.0       803.0       330.0        82.0        657.0
#
#        time.Mon-20  time.Tue-16  time.Thu-22  time.Fri-21  time.Sun-9  \
# 24463        952.0       1072.0       1084.0       1199.0        10.0
#
#           ...       time.Thu-15  time.Thu-23  time.Sun-8  time.Sun-6  \
# 24463     ...            1156.0       1028.0        23.0       173.0
#
#        time.Fri-1  time.Fri-17  time.Wed-19  time.Mon-13  time.Sun-3  \
# 24463      1332.0        977.0        823.0        929.0       424.0
#
#        time.Wed-14
# 24463        966.0
#
# [1 rows x 169 columns]
